# %%
import pandas as pd

# %%
df=pd.read_csv('insurance.csv')

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
X=df.iloc[:3,2].values
X
# Out:
# array([27.9 , 33.77, 33.  ])

# %% [markdown]
# # Using Gadient Decent for Independent Variable BMI

# %%
X_true=df['bmi']

# %%
X_true
# Out:
# 0       27.900
# 1       33.770
# 2       33.000
# 3       22.705
# 4       28.880
#          ...
# 1333    30.970
# 1334    31.920
# 1335    36.850
# 1336    25.800
# 1337    29.070
# Name: bmi, Length: 1338, dtype: float64

# %%
Y_true=df['charges']

# %%
Y_true
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
from IPython import display
display.Image('E:\\DSML\\dm.jpg')

# %%
display.Image('E:\\DSML\\dc.jpg')

# %%
import matplotlib.pyplot as plt
import numpy as np

n=len(X_true)
def mean_squared_error_func(Y_true,Y_pred):
    cost=sum((Y_true-Y_pred)**2/n)
    return cost

def gradient_Function():
    iteration=2000
    learning_rate=0.0001
    current_weight=0
    current_intercept=0
    stopping_threshold = 1e-6
    previous_cost=None
    
    costs=[]
    weights=[]
    
    for i in range(iteration):
        Y_pred=(current_weight*X_true)+current_intercept
        current_cost=mean_squared_error_func(Y_true,Y_pred)
        if previous_cost and abs(previous_cost-current_cost)<=stopping_threshold:
            break
        previous_cost=current_cost
        
        costs.append(current_cost)
        weights.append(current_weight)
        
        #Calculating Gradient
        weight_derivative=(-2/n)*sum(X_true*(Y_true-Y_pred))
        intercept_derivative = -(2/n) * sum(Y_true-Y_pred)
        
        current_weight=current_weight-(learning_rate*weight_derivative)
        current_intercept=current_intercept-(learning_rate*intercept_derivative)
        print(f'Iteration {i}: Cost Function {current_cost} Weight {current_weight} Intercept {current_intercept}')
    plt.figure(figsize=(10,12))
    plt.plot(weights,costs)
    plt.scatter(weights,costs,marker='o',color='red')
    plt.title("Cost vs Weights")
    plt.ylabel("Cost")
    plt.xlabel("Weight")
    plt.show()
    
    return current_weight,current_intercept

def main():
    estimated_weight,estimated_intercerpt=gradient_Function()
    print(f"Estimated Weight: {estimated_weight} Estimated Intercept: {estimated_intercerpt}")
    
    Y_pred=(estimated_weight*29.070	)+estimated_intercerpt
    #plt.figure(figsize = (8,6))
    #plt.scatter(X, Y, marker='o', color='red')
   # plt.plot([min(X), max(X)], [min(Y_pred), max(Y_pred)], color='blue',markerfacecolor='red',
            # markersize=10,linestyle='dashed')
   # plt.xlabel("X")
   # plt.ylabel("Y")
   # plt.show()
    print(Y_pred)
 
if __name__=="__main__":
    main()
# Out:
# Iteration 0: Cost Function 322646873.5887042 Weight 84.3105163383943 Intercept 2.6540844530282515
# Iteration 1: Cost Function 258455175.09400645 Weight 152.123668895664 Intercept 4.790588724758121
# Iteration 2: Cost Function 216926894.91732964 Weight 206.66754968513337 Intercept 6.510789373782011
# Iteration 3: Cost Function 190060522.7648085 Weight 250.5385996161446 Intercept 7.896145850078925
# Iteration 4: Cost Function 172679548.79416075 Weight 285.8252056887834 Intercept 9.012178172132032
# Iteration 5: Cost Function 161435073.46478856 Weight 314.20711352962394 Intercept 9.9115858465442
# Iteration 6: Cost Function 154160554.3620658 Weight 337.0353875581823 Intercept 10.636756498662361
# Iteration 7: Cost Function 149454365.07783553 Weight 355.3967250914833 Intercept 11.22178363141229
# Iteration 8: Cost Function 146409735.186196 Weight 370.1651859017851 Intercept 11.694089562799242
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
m=0
c=0
L=0.0001
weights=[]
costs=[]
n=len(X)
itr=2000

for i in range(itr):
    Y_pred=m*X+c 
    current_cost=np.sum((Y-Y_pred)**2) / len(Y)    # mean_queared Error
    costs.append(current_cost)
    Dm=(-2/n)*sum(X*(Y-Y_pred))                    #weight_derivative
    Dc=(-2/n)*sum(Y-Y_pred)                        # Intercept Derivative
    #update M & C
    m=m-L*Dm
    weights.append(m)
    c=c-L*Dc
    print(m,c)

print(weights,costs)
plt.plot(weights,costs)
plt.scatter(weights,costs,marker='o',color='red')
plt.title('Costs vs Weight')
plt.xlabel('Weight')
plt.ylabel('Costs')
plt.show()
# Out:
# 84.3105163383943 2.6540844530282515
# 152.123668895664 4.790588724758121
# 206.66754968513337 6.510789373782011
# 250.5385996161446 7.896145850078925
# 285.8252056887834 9.012178172132032
# 314.20711352962394 9.9115858465442
# 337.0353875581823 10.636756498662361
# 355.3967250914833 11.22178363141229
# 370.1651859017851 11.694089562799242
# 382.04379968605264 12.075730798029474
# 391.59803206860755 12.384447975287584
# 399.2827022038468 12.634510365260567
# 405.4636333254186 12.837395124735034
# 410.4350668630938 13.00233363846737
# 414.4336690836105 13.136750956590209
# 417.6497970072405 13.246619245894038
# 420.2365598863765 13.336742080164413
# 422.31710759557893 13.41098310251829
# 423.9904928789981 13.4724499446486
# 425.3363865130658 13.52364215800112
# 426.41886983819984 13.56657019878415
# 427.289485193683 13.602851130800227
# 427.98968946417796 13.63378560179821
# 428.552827532937 13.660419757616006
# 429.0057195831012 13.68359504138466
# ...

# %%
pred_Y=m*27.900+c
pred_Y
# Out:
# 12037.162895836847

# %% [markdown]
# # Multi Variable Regression

# %%
df=pd.read_csv('insurance.csv')

# %%
dfe=df.copy()

# %%
dfe
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
dfe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
dfe.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# # Encoding Manual, Label, Onehot

# %%
dfe['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
dfe.sex=dfe.sex.replace(['female','male'],['0','1']) #Manual Encoding Sex

# %%
dfe
# Out:
#       age sex     bmi  children smoker     region      charges
# 0      19   0  27.900         0    yes  southwest  16884.92400
# 1      18   1  33.770         1     no  southeast   1725.55230
# 2      28   1  33.000         3     no  southeast   4449.46200
# 3      33   1  22.705         0     no  northwest  21984.47061
# 4      32   1  28.880         0     no  northwest   3866.85520
# ...   ...  ..     ...       ...    ...        ...          ...
# 1333   50   1  30.970         3     no  northwest  10600.54830
# 1334   18   0  31.920         0     no  northeast   2205.98080
# 1335   18   0  36.850         0     no  southeast   1629.83350
# 1336   21   0  25.800         0     no  southwest   2007.94500
# 1337   61   0  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
from sklearn.preprocessing import LabelEncoder  #label Encoding for Smoker

# %%
le=LabelEncoder()       #Label Encoder

# %%
dfe['smoker']=le.fit_transform(dfe['smoker'])

# %%
dfe
# Out:
#       age sex     bmi  children  smoker     region      charges
# 0      19   0  27.900         0       1  southwest  16884.92400
# 1      18   1  33.770         1       0  southeast   1725.55230
# 2      28   1  33.000         3       0  southeast   4449.46200
# 3      33   1  22.705         0       0  northwest  21984.47061
# 4      32   1  28.880         0       0  northwest   3866.85520
# ...   ...  ..     ...       ...     ...        ...          ...
# 1333   50   1  30.970         3       0  northwest  10600.54830
# 1334   18   0  31.920         0       0  northeast   2205.98080
# 1335   18   0  36.850         0       0  southeast   1629.83350
# 1336   21   0  25.800         0       0  southwest   2007.94500
# 1337   61   0  29.070         0       1  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
from sklearn.preprocessing import OneHotEncoder           # One Hot Encoder for Region

# %%
dummy=pd.get_dummies(dfe['region'],drop_first=True,prefix='region')

# %%
dfe.drop('region',axis=1,inplace=True)

# %%
dfe
# Out:
#       age sex     bmi  children  smoker      charges
# 0      19   0  27.900         0       1  16884.92400
# 1      18   1  33.770         1       0   1725.55230
# 2      28   1  33.000         3       0   4449.46200
# 3      33   1  22.705         0       0  21984.47061
# 4      32   1  28.880         0       0   3866.85520
# ...   ...  ..     ...       ...     ...          ...
# 1333   50   1  30.970         3       0  10600.54830
# 1334   18   0  31.920         0       0   2205.98080
# 1335   18   0  36.850         0       0   1629.83350
# 1336   21   0  25.800         0       0   2007.94500
# 1337   61   0  29.070         0       1  29141.36030
#
# [1338 rows x 6 columns]

# %%
dfe=pd.concat([dfe,dummy],axis=1)

# %%
dfe
# Out:
#       age sex     bmi  children  smoker      charges  region_northwest  \
# 0      19   0  27.900         0       1  16884.92400                 0
# 1      18   1  33.770         1       0   1725.55230                 0
# 2      28   1  33.000         3       0   4449.46200                 0
# 3      33   1  22.705         0       0  21984.47061                 1
# 4      32   1  28.880         0       0   3866.85520                 1
# ...   ...  ..     ...       ...     ...          ...               ...
# 1333   50   1  30.970         3       0  10600.54830                 1
# 1334   18   0  31.920         0       0   2205.98080                 0
# 1335   18   0  36.850         0       0   1629.83350                 0
# 1336   21   0  25.800         0       0   2007.94500                 0
# 1337   61   0  29.070         0       1  29141.36030                 1
#
#       region_southeast  region_southwest
# 0                    0                 1
# ...

# %%
X=dfe.drop('charges',axis=1)
Y=dfe[['charges']]

# %%
X
# Out:
#       age sex     bmi  children  smoker  region_northwest  region_southeast  \
# 0      19   0  27.900         0       1                 0                 0
# 1      18   1  33.770         1       0                 0                 1
# 2      28   1  33.000         3       0                 0                 1
# 3      33   1  22.705         0       0                 1                 0
# 4      32   1  28.880         0       0                 1                 0
# ...   ...  ..     ...       ...     ...               ...               ...
# 1333   50   1  30.970         3       0                 1                 0
# 1334   18   0  31.920         0       0                 0                 0
# 1335   18   0  36.850         0       0                 0                 1
# 1336   21   0  25.800         0       0                 0                 0
# 1337   61   0  29.070         0       1                 1                 0
#
#       region_southwest
# 0                    1
# ...

# %%
Y
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
X_train
# Out:
#       age sex     bmi  children  smoker  region_northwest  region_southeast  \
# 621    37   1  34.100         4       1                 0                 0
# 194    18   1  34.430         0       0                 0                 1
# 240    23   0  36.670         2       1                 0                 0
# 1168   32   1  35.200         2       0                 0                 0
# 1192   58   0  32.395         1       0                 0                 0
# ...   ...  ..     ...       ...     ...               ...               ...
# 763    27   1  26.030         0       0                 0                 0
# 835    42   1  35.970         2       0                 0                 1
# 1216   40   1  25.080         0       0                 0                 1
# 559    19   1  35.530         0       0                 1                 0
# 684    33   0  18.500         1       0                 0                 0
#
#       region_southwest
# 621                  1
# ...

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()

# %%
reg.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred=reg.predict(X_test)

# %%
print(Y_pred)
# Out:
# [[1.11699271e+04]
#  [9.48670909e+03]
#  [3.81811231e+04]
#  [1.62663133e+04]
#  [6.91464801e+03]
#  [3.96348488e+03]
#  [1.57939691e+03]
#  [1.43852566e+04]
#  [9.01257970e+03]
#  [7.50846068e+03]
#  [4.49176728e+03]
#  [1.02795839e+04]
#  [8.80129751e+03]
#  [3.79802013e+03]
#  [2.79262010e+04]
#  [1.07151158e+04]
#  [1.12889756e+04]
#  [6.10501768e+03]
#  [8.24104117e+03]
#  [2.71445089e+04]
#  [3.36440910e+04]
#  [1.43551043e+04]
#  [1.17372043e+04]
#  [3.21374335e+04]
#  [4.17005913e+03]
#  [9.25496051e+03]
#  [1.08433751e+03]
#  [9.80417085e+03]
#  [3.77104596e+03]
#  [1.04318587e+04]
#  [9.00931722e+03]
#  [4.00749509e+04]
#  [1.56889543e+04]
#  [1.38794545e+04]
#  [2.47597127e+04]
#  [5.16638285e+03]
#  [1.26109277e+04]
#  [3.07691018e+04]
#  [3.35498325e+04]
#  [3.67154946e+03]
#  [3.97568613e+03]
#  [3.98729942e+03]
#  [3.05285774e+04]
#  [3.95053023e+04]
#  [2.78105036e+04]
#  [5.09258923e+03]
#  [1.06042481e+04]
#  [7.82952256e+03]
#  [3.59255553e+03]
#  [1.02128745e+04]
# ...

# %% [markdown]
# # Accuracy of the Model r2_score
# r2 = 1 – (SSres  /SSmean )   SSres=(1/n)*sum(Y-Y_pred)

# %%
from IPython import display
display.Image('E:\\DSML\\r2_Score formula.jpg')

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score

# %%
score=r2_score(Y_test,Y_pred)
score
# Out:
# 0.7999876970680434

# %%
print('Mean Squared Error:',mean_squared_error(Y_test,Y_pred))
print('Mean Absolute Error:',mean_absolute_error(Y_test,Y_pred))
# Out:
# Mean Squared Error: 31827950.229523834
# Mean Absolute Error: 3933.2726494052367

# %%
m=reg.coef_
m
# Out:
# array([[ 2.53700500e+02, -1.54637279e+01,  3.35962814e+02,
#          4.36910121e+02,  2.36050173e+04, -2.60132732e+02,
#         -9.13278834e+02, -7.61948706e+02]])

# %%
c=reg.intercept_
c
# Out:
# array([-11828.07353747])
